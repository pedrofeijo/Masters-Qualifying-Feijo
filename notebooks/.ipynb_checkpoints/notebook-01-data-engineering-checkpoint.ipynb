# %%
import pandas as pd
from sklearn.model_selection import StratifiedShuffleSplit
import os
import warnings
warnings.filterwarnings('ignore')

DATAFOLDER = os.path.join('..', 'data', 'csv')
DATAS = ['v000_SCIG_SC_SENSORA_FOURIER.csv', 'v000_SCIG_SC_SENSORA_HOS.csv', 'v000_SCIG_SC_SENSORA_SCM.csv']
SEED = 6969
TEST_SIZE = 10

# %% [markdown]
# # Load data

# %%
data_fourier = pd.read_csv(os.path.join(DATAFOLDER, DATA_FOURIER))
data_fourier.sort_values(by='Class', inplace=True)
data_fourier.head()
# Out:
#       idx     fx1_R   fx0d5_R   fx1d5_R   fx2d5_R     fx3_R     fx5_R  \
# 1324  248  0.429819  0.056827  0.062056  0.046355  0.129908  0.291088
# 1166   90  1.134724  0.023278  0.050340  0.022604  0.147467  0.384467
# 1165   89  1.200866  0.051206  0.054370  0.032890  0.219454  0.386371
# 1164   88  1.133127  0.010273  0.026542  0.017223  0.147249  0.381923
# 1163   87  0.969220  0.029723  0.026360  0.024754  0.185335  0.381358
#
#          fx7_R  Freq_Rated  Freq_Gen  CC_bus  Power   I_R_rms   I_S_rms  \
# 1324  0.302811        60.0     59.55     210   0.10  1.184284  1.188929
# 1166  0.328781        50.0     49.32     312   0.30  1.962905  1.965152
# 1165  0.414355        50.0     49.30     318   0.31  2.022776  2.022801
# 1164  0.396297        50.0     49.28     322   0.33  2.075326  2.073279
# 1163  0.356301        50.0     49.26     327   0.34  2.128882  2.126525
#
#        I_T_rms  Load  Class
# 1324  1.197345     0      1
# 1166  2.004029     0      1
# ...

# %%
sss = StratifiedShuffleSplit(n_splits=2, test_size=TEST_SIZE, random_state=SEED)
for train_index, test_index in sss.split(X, y):
    print("TRAIN:", train_index, "TEST:", test_index)
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
